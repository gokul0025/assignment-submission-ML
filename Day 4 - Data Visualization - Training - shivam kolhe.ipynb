# %% [markdown]
# # Day 4 - Data Visualization

# %%
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# #### Import Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

# %% [markdown]
# #### Load a sample data from Seaborn inbuilt data library

# %%
data = sns.load_dataset('tips')

data.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# #### Save the dataset ina CSV file

# %%
data.to_csv('tips_data.csv', index=False)

# %% [markdown]
# #### Read the dataset from external CSV File

# %%
pd.read_csv('C:/dataset/tips_data.csv')

# %%
pd.read_csv('tips_data.csv')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### Understand the data

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.shape
# Out:
# (244, 7)

# %%
data.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # Bar Chart
#
# Bar chart is a frequency chart for qualitative variable (or categorical variable). Bar chart can be used to
# assess the most-occurring and least-occurring categories within a dataset.

# %% [markdown]
# #### set plot size

# %%
plt.rcParams['figure.figsize'] = [10,5]

# %%
sns.barplot(x = 'sex', y='tip', data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x = 'sex', y = 'tip', hue = 'smoker', data = data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %% [markdown]
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
sns.barplot(x = 'tip', y = 'sex', hue = 'time', palette = 'winter', data=data)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='sex'>

# %% [markdown]
# # Histogram
#
# A histogram is a plot that shows the frequency distribution of a set of continuous variable. Histogram
# gives an insight into the
#     - underlying distribution of the variable
#     - outliers
#     - skewness

# %%
plt.hist(data['total_bill'], bins = 20)
# Out:
# (array([ 1.,  6., 13., 29., 31., 37., 28., 23., 18., 13., 10.,  9.,  5.,
#          7.,  3.,  4.,  1.,  2.,  3.,  1.]),
#  array([ 3.07 ,  5.457,  7.844, 10.231, 12.618, 15.005, 17.392, 19.779,
#         22.166, 24.553, 26.94 , 29.327, 31.714, 34.101, 36.488, 38.875,
#         41.262, 43.649, 46.036, 48.423, 50.81 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# # Distribution Plot

# %% [markdown]
# A distribution or density plot depicts the distribution of data over a continuous interval. Density plot
# is like smoothed histogram and visualizes distribution of data over a continuous interval.

# %%
sns.distplot(data['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.distplot(data['total_bill'], color = 'g')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# # Countplot

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.sex.value_counts() / data.shape[0] * 100
# Out:
# Male      64.344262
# Female    35.655738
# Name: sex, dtype: float64

# %% [markdown]
# #### Another way of plotting countplot

# %%
sns.countplot('sex', data=data, palette = 'dark')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot('smoker', data=data, palette = 'hls')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %% [markdown]
# # Boxplot
#
# Used to understand the variability of the data and the existence of outliers. Box plot is designed by identifying
# the following descriptive statistics:
#     1. Lower quartile (1st quartile), median and upper quartile (3rd quartile).
#     2. Lowest and highest values.
#     3. Inter-quartile range (IQR).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.boxplot('total_bill', data = data, palette = 'husl')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.distplot(data['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.boxplot('smoker', 'total_bill', data=data)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
box = plt.boxplot('total_bill', data=data)

# %% [markdown]
# #### The whiskers key in box variable returns the values of the distribution at 25 and 75 quantiles.

# %% [markdown]
# #### Get Q1 and Q3

# %%
q1_q3 = [item.get_ydata()[0] for item in box['whiskers']]

# %% [markdown]
# ## What will be value of IQR = ?

# %%
q1_q3[1] - q1_q3[0]
# Out:
# 10.779999999999998

# %% [markdown]
# #### Get Lower and Upper Extreme

# %%
[item.get_ydata()[0] for item in box['caps']]
# Out:
# [3.07, 40.17]

# %% [markdown]
# #### Get Median

# %%
[item.get_ydata()[0] for item in box['medians']]
# Out:
# [17.795]

# %% [markdown]
# ## Get Outliers

# %%
data[data['total_bill'] > 40.17]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4

# %% [markdown]
# # Scatterplot
#
# In a scatter plot, the values of two variables are plotted along two axes and resulting pattern can reveal correlation present between the variables.

# %%
sns.scatterplot('total_bill', 'tip', data = data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot('total_bill', 'tip', data = data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>
